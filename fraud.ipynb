# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **신용거래 이상 탐지 프로젝트**

# %%
#데이터 불러오기
fraud = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fraud.csv')

# %% [markdown]
# 데이터 기본정보 확인

# %%
fraud.head()
# Out:
#   trans_date_trans_time               cc_num  \
# 0   2019-01-01 00:00:44         630423337322
# 1   2019-01-01 00:12:34  4956828990005111019
# 2   2019-01-01 00:17:16      180048185037117
# 3   2019-01-01 00:20:15      374930071163758
# 4   2019-01-01 00:23:41     2712209726293386
#
#                             merchant     category     amt      first  \
# 0    fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie
# 1  fraud_Schultz, Simonis and Little  grocery_pos   44.71    Kenneth
# 2                  fraud_Kling-Grant  grocery_net   46.28       Mary
# 3              fraud_Deckow-O'Conner  grocery_pos   64.09     Daniel
# 4             fraud_Balistreri-Nader     misc_pos   25.58      Jenna
#
#        last gender                        street         city  ...      lat  \
# 0      Gill      F  43039 Riley Greens Suite 393       Orient  ...  48.8878
# 1  Robinson      M            269 Sanchez Rapids    Elizabeth  ...  40.6747
# ...

# %% [markdown]
# 중간에 컬럼이 안보이기에 pd.set_option 사용 22개의 컬럼을 전부 확인할 필요가 있어보임

# %%
#22개의 컬럼이지만 여유롭게 30컬럼을 보이게끔 설정
pd.set_option('display.max_columns', 30)

# %%
fraud.head()
# Out:
#   trans_date_trans_time               cc_num  \
# 0   2019-01-01 00:00:44         630423337322
# 1   2019-01-01 00:12:34  4956828990005111019
# 2   2019-01-01 00:17:16      180048185037117
# 3   2019-01-01 00:20:15      374930071163758
# 4   2019-01-01 00:23:41     2712209726293386
#
#                             merchant     category     amt      first  \
# 0    fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie
# 1  fraud_Schultz, Simonis and Little  grocery_pos   44.71    Kenneth
# 2                  fraud_Kling-Grant  grocery_net   46.28       Mary
# 3              fraud_Deckow-O'Conner  grocery_pos   64.09     Daniel
# 4             fraud_Balistreri-Nader     misc_pos   25.58      Jenna
#
#        last gender                        street         city state    zip  \
# 0      Gill      F  43039 Riley Greens Suite 393       Orient    WA  99160
# 1  Robinson      M            269 Sanchez Rapids    Elizabeth    NJ   7208
# ...

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491134 entries, 0 to 491133
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  491134 non-null  object
#  1   cc_num                 491134 non-null  int64
#  2   merchant               491134 non-null  object
#  3   category               491134 non-null  object
#  4   amt                    491134 non-null  float64
#  5   first                  491134 non-null  object
#  6   last                   491134 non-null  object
#  7   gender                 491134 non-null  object
#  8   street                 491134 non-null  object
#  9   city                   491134 non-null  object
#  10  state                  491134 non-null  object
#  11  zip                    491134 non-null  int64
#  12  lat                    491134 non-null  float64
#  13  long                   491134 non-null  float64
# ...

# %%
fraud.describe()
# Out:
#              cc_num            amt            zip            lat  \
# count  4.911340e+05  491134.000000  491134.000000  491134.000000
# mean   3.706013e+17      69.050120   50770.532384      37.931230
# std    1.260229e+18     160.322867   26854.947965       5.341193
# min    5.038744e+11       1.000000    1843.000000      24.655700
# 25%    2.131124e+14       8.960000   28405.000000      33.746700
# 50%    3.531130e+15      42.170000   49628.000000      38.507200
# 75%    4.653879e+15      80.330000   75048.000000      41.520500
# max    4.956829e+18   25086.940000   99323.000000      48.887800
#
#                 long      city_pop     unix_time      merch_lat  \
# count  491134.000000  4.911340e+05  4.911340e+05  491134.000000
# mean      -90.495619  1.213922e+05  1.358730e+09      37.930272
# std        12.990732  3.725751e+05  1.819402e+07       5.372986
# min      -122.345600  4.600000e+01  1.325376e+09      23.655789
# ...

# %% [markdown]
# info()로 확인 결과 결측치는 보이지 않는 것으로 확인
# 이상치는 사기거래 여부에 필요함으로 이상치 처리는 생략

# %% [markdown]
# 사기거래 여부에 불필요한 컬럼 삭제

# %%
fraud.head(1)
# Out:
#   trans_date_trans_time        cc_num                         merchant  \
# 0   2019-01-01 00:00:44  630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first  last gender                        street  \
# 0  grocery_pos  107.23  Stephanie  Gill      F  43039 Riley Greens Suite 393
#
#      city state    zip      lat      long  city_pop  \
# 0  Orient    WA  99160  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
#
#    is_fraud
# 0         0

# %%
#사기거래 여부에 필요없는 컬럼을 드랍
fraud.head(1)
# Out:
#   trans_date_trans_time        cc_num                         merchant  \
# 0   2019-01-01 00:00:44  630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first  last gender                        street  \
# 0  grocery_pos  107.23  Stephanie  Gill      F  43039 Riley Greens Suite 393
#
#      city state    zip      lat      long  city_pop  \
# 0  Orient    WA  99160  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
#
#    is_fraud
# 0         0

# %%
fraud.rename({'city_pop':'pop'},axis=1,inplace= True)

# %% [markdown]
# city컬럼을 드랍시 city_pop도 드랍이 됨 city_pop은 필요할 것으로 판단되어 컬럼명을 변경

# %%
fraud_df = fraud.drop(['trans_date_trans_time','cc_num','first','last','street','city','state','zip','dob','trans_num','gender'],axis = 1)

# %%
fraud_df
# Out:
#                                     merchant       category     amt      lat  \
# 0            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  48.8878
# 1          fraud_Schultz, Simonis and Little    grocery_pos   44.71  40.6747
# 2                          fraud_Kling-Grant    grocery_net   46.28  40.6152
# 3                      fraud_Deckow-O'Conner    grocery_pos   64.09  42.2203
# 4                     fraud_Balistreri-Nader       misc_pos   25.58  30.4066
# ...                                      ...            ...     ...      ...
# 491129               fraud_Botsford and Sons           home  134.26  34.2651
# 491130  fraud_Baumbach, Hodkiewicz and Walsh   shopping_pos   25.49  34.0326
# 491131                  fraud_Hoppe-Parisian      kids_pets  111.84  29.0393
# 491132                       fraud_Rau-Robel      kids_pets   86.88  46.1966
# 491133                     fraud_Dare-Marvin  entertainment   38.13  35.6665
#
# ...

# %% [markdown]
# 최소 2개이상 새로운 피쳐(변수)생성

# %%
#구매 금액으로 이상치 금액 변환
fraud_df['amt_log'] = np.log1p(fraud_df['amt'])

# %%
# unix_time으로 새로운 피쳐 생성 및 날짜별 분할
fraud_df['trans_datetime'] = pd.to_datetime(fraud_df['unix_time'], unit='s')
fraud_df['year'] = fraud_df['trans_datetime'].dt.year
fraud_df['month'] = fraud_df['trans_datetime'].dt.month
fraud_df['day'] = fraud_df['trans_datetime'].dt.day
fraud_df['hour'] = fraud_df['trans_datetime'].dt.hour
fraud_df['minuete'] = fraud_df['trans_datetime'].dt.minute
fraud_df['second'] = fraud_df['trans_datetime'].dt.second
fraud_df['weekday'] = fraud_df['trans_datetime'].dt.dayofweek #0 = 월요일

# %%
fraud_df
# Out:
#                                     merchant       category     amt      lat  \
# 0            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  48.8878
# 1          fraud_Schultz, Simonis and Little    grocery_pos   44.71  40.6747
# 2                          fraud_Kling-Grant    grocery_net   46.28  40.6152
# 3                      fraud_Deckow-O'Conner    grocery_pos   64.09  42.2203
# 4                     fraud_Balistreri-Nader       misc_pos   25.58  30.4066
# ...                                      ...            ...     ...      ...
# 491129               fraud_Botsford and Sons           home  134.26  34.2651
# 491130  fraud_Baumbach, Hodkiewicz and Walsh   shopping_pos   25.49  34.0326
# 491131                  fraud_Hoppe-Parisian      kids_pets  111.84  29.0393
# 491132                       fraud_Rau-Robel      kids_pets   86.88  46.1966
# 491133                     fraud_Dare-Marvin  entertainment   38.13  35.6665
#
# ...

# %%
fraud_df.head()
# Out:
#                             merchant     category     amt      lat      long  \
# 0    fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  48.8878 -118.2105
# 1  fraud_Schultz, Simonis and Little  grocery_pos   44.71  40.6747  -74.2239
# 2                  fraud_Kling-Grant  grocery_net   46.28  40.6152  -74.4150
# 3              fraud_Deckow-O'Conner  grocery_pos   64.09  42.2203  -83.3583
# 4             fraud_Balistreri-Nader     misc_pos   25.58  30.4066  -91.1468
#
#       pop                                job   unix_time  merch_lat  \
# 0     149  Special educational needs teacher  1325376044  49.159047
# 1  124967             Operational researcher  1325376754  40.079588
# 2   71485             Leisure centre manager  1325377036  40.021888
# 3   31515                     Police officer  1325377215  42.360426
# 4  378909                Designer, furniture  1325377421  29.737426
#
#    merch_long  is_fraud   amt_log      trans_datetime  year  month  day  hour  \
# ...

# %%
fraud_df['merchant'].nunique()
# Out:
# 693

# %%
fraud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491134 entries, 0 to 491133
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   merchant        491134 non-null  object
#  1   category        491134 non-null  object
#  2   amt             491134 non-null  float64
#  3   lat             491134 non-null  float64
#  4   long            491134 non-null  float64
#  5   pop             491134 non-null  int64
#  6   job             491134 non-null  object
#  7   unix_time       491134 non-null  int64
#  8   merch_lat       491134 non-null  float64
#  9   merch_long      491134 non-null  float64
#  10  is_fraud        491134 non-null  int64
#  11  amt_log         491134 non-null  float64
#  12  trans_datetime  491134 non-null  datetime64[ns]
#  13  year            491134 non-null  int32
#  14  month           491134 non-null  int32
#  15  day             491134 non-null  int32
# ...

# %%
fraud_df.describe()
# Out:
#                  amt            lat           long           pop  \
# count  491134.000000  491134.000000  491134.000000  4.911340e+05
# mean       69.050120      37.931230     -90.495619  1.213922e+05
# min         1.000000      24.655700    -122.345600  4.600000e+01
# 25%         8.960000      33.746700     -97.235100  1.228000e+03
# 50%        42.170000      38.507200     -87.591700  5.760000e+03
# 75%        80.330000      41.520500     -80.731000  5.083500e+04
# max     25086.940000      48.887800     -69.965600  2.906700e+06
# std       160.322867       5.341193      12.990732  3.725751e+05
#
#           unix_time      merch_lat     merch_long       is_fraud  \
# count  4.911340e+05  491134.000000  491134.000000  491134.000000
# mean   1.358730e+09      37.930272     -90.495411       0.002533
# min    1.325376e+09      23.655789    -123.345106       0.000000
# 25%    1.343087e+09      33.781388     -96.984814       0.000000
# ...

# %%
#중복데이터 확인
fraud_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#결측치 확인
fraud_df.isna().sum()
# Out:
# merchant          0
# category          0
# amt               0
# lat               0
# long              0
# pop               0
# job               0
# unix_time         0
# merch_lat         0
# merch_long        0
# is_fraud          0
# amt_log           0
# trans_datetime    0
# year              0
# month             0
# day               0
# hour              0
# minuete           0
# second            0
# weekday           0
# dtype: int64

# %% [markdown]
# 모델제작을 위해 category 컬럼을 원 핫인코딩

# %%
df = pd.get_dummies(fraud_df, columns =['category'],dtype = int,drop_first = True)
df
# Out:
#                                     merchant     amt      lat      long  \
# 0            fraud_Heller, Gutmann and Zieme  107.23  48.8878 -118.2105
# 1          fraud_Schultz, Simonis and Little   44.71  40.6747  -74.2239
# 2                          fraud_Kling-Grant   46.28  40.6152  -74.4150
# 3                      fraud_Deckow-O'Conner   64.09  42.2203  -83.3583
# 4                     fraud_Balistreri-Nader   25.58  30.4066  -91.1468
# ...                                      ...     ...      ...       ...
# 491129               fraud_Botsford and Sons  134.26  34.2651  -77.8670
# 491130  fraud_Baumbach, Hodkiewicz and Walsh   25.49  34.0326  -82.2027
# 491131                  fraud_Hoppe-Parisian  111.84  29.0393  -95.4401
# 491132                       fraud_Rau-Robel   86.88  46.1966 -118.9017
# 491133                     fraud_Dare-Marvin   38.13  35.6665  -97.4798
#
#            pop                                     job   unix_time  merch_lat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491134 entries, 0 to 491133
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   merchant                 491134 non-null  object
#  1   amt                      491134 non-null  float64
#  2   lat                      491134 non-null  float64
#  3   long                     491134 non-null  float64
#  4   pop                      491134 non-null  int64
#  5   job                      491134 non-null  object
#  6   unix_time                491134 non-null  int64
#  7   merch_lat                491134 non-null  float64
#  8   merch_long               491134 non-null  float64
#  9   is_fraud                 491134 non-null  int64
#  10  amt_log                  491134 non-null  float64
#  11  trans_datetime           491134 non-null  datetime64[ns]
#  12  year                     491134 non-null  int32
# ...

# %%
#merchant 와 job을 원핫 인코딩을하면 컬럼 수가 기하급수적으로 많아지기에 숫자형(amt컬럼은 amt_log와 겹쳐서 드랍) 제외한 나머지 컬럼을 드랍하기로 결정
frauded = df.drop(['amt','merchant','job','unix_time'],axis=1)

# %%
#시간 순으로 정렬
frauded = frauded.sort_values('trans_datetime',ascending=True)

# %%
frauded.head()
# Out:
#        lat      long     pop  merch_lat  merch_long  is_fraud   amt_log  \
# 0  48.8878 -118.2105     149  49.159047 -118.186462         0  4.684259
# 1  40.6747  -74.2239  124967  40.079588  -74.848087         0  3.822317
# 2  40.6152  -74.4150   71485  40.021888  -74.228188         0  3.856087
# 3  42.2203  -83.3583   31515  42.360426  -83.552316         0  4.175771
# 4  30.4066  -91.1468  378909  29.737426  -90.853194         0  3.280159
#
#        trans_datetime  year  month  day  hour  minuete  second  weekday  \
# 0 2012-01-01 00:00:44  2012      1    1     0        0      44        6
# 1 2012-01-01 00:12:34  2012      1    1     0       12      34        6
# 2 2012-01-01 00:17:16  2012      1    1     0       17      16        6
# 3 2012-01-01 00:20:15  2012      1    1     0       20      15        6
# 4 2012-01-01 00:23:41  2012      1    1     0       23      41        6
#
#    category_food_dining  category_gas_transport  category_grocery_net  \
# ...

# %%
frauded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491134 entries, 0 to 491133
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   lat                      491134 non-null  float64
#  1   long                     491134 non-null  float64
#  2   pop                      491134 non-null  int64
#  3   merch_lat                491134 non-null  float64
#  4   merch_long               491134 non-null  float64
#  5   is_fraud                 491134 non-null  int64
#  6   amt_log                  491134 non-null  float64
#  7   trans_datetime           491134 non-null  datetime64[ns]
#  8   year                     491134 non-null  int32
#  9   month                    491134 non-null  int32
#  10  day                      491134 non-null  int32
#  11  hour                     491134 non-null  int32
#  12  minuete                  491134 non-null  int32
# ...

# %% [markdown]
# SMOTE 기법 사용 XGBoost 활용

# %%
#필요한 라이브러리 불러오기
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, recall_score
from xgboost import XGBClassifier

# %%
train = frauded[frauded['trans_datetime'] < '2013-12-31']
test  = frauded[frauded['trans_datetime'] >= '2012-01-01']

#X, y 분리
X_train = train.drop(['is_fraud', 'trans_datetime'], axis=1)
y_train = train['is_fraud']

X_test = test.drop(['is_fraud', 'trans_datetime'], axis=1)
y_test = test['is_fraud']

#SMOTE (Train에만)
smote = SMOTE(random_state=43)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

print("Before SMOTE:")
print(y_train.value_counts())
print("\nAfter SMOTE:")
print(y_train_res.value_counts())
# Out:
# Before SMOTE:
# is_fraud
# 0    488966
# 1      1244
# Name: count, dtype: int64
#
# After SMOTE:
# is_fraud
# 0    488966
# 1    488966
# Name: count, dtype: int64

# %%
pos = y_train_res.sum()
neg = len(y_train_res) - pos
scale_pos_weight = neg / pos

model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='binary:logistic',
    eval_metric='logloss',
    scale_pos_weight=scale_pos_weight,
    random_state=42
)

# %%
model.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print('\n')
print(classification_report(y_test, y_pred))
print('\n')
print("Recall:", recall_score(y_test, y_pred))
# Out:
# [[473555  16335]
#  [   143   1101]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98    489890
#            1       0.06      0.89      0.12      1244
#
#     accuracy                           0.97    491134
#    macro avg       0.53      0.93      0.55    491134
# weighted avg       1.00      0.97      0.98    491134
#
#
#
# Recall: 0.885048231511254
